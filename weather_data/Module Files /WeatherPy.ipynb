# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
#generating random lats_lngs zip
lats = np.random.uniform(-90.000, 90.000, size = 1500)
lngs = np.random.uniform(-180.000, 180.000, size = 1500)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
cities = []

#identifying cities for random lat_lngs zip
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

#weather url 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
len(cities)
# Out:
# 606

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through cities in list
for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    #endpoint url
    city_url = url + "&q=" + city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | asau
# City not found. Skipping...
# Processing Record 2 of Set 1 | yumen
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | isangel
# Processing Record 6 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | hirara
# Processing Record 12 of Set 1 | kaifeng
# Processing Record 13 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 1 | saint-pierre
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | ballina
# Processing Record 18 of Set 1 | bonthe
# Processing Record 19 of Set 1 | fairbanks
# Processing Record 20 of Set 1 | terrace
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 23 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 1 | hervey bay
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | souillac
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | oktyabrskiy
# Processing Record 31 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 32 of Set 1 | namatanai
# Processing Record 33 of Set 1 | kalabo
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | vardo
# Processing Record 41 of Set 1 | yulara
# Processing Record 42 of Set 1 | berlevag
# Processing Record 43 of Set 1 | khani
# Processing Record 44 of Set 1 | mount isa
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | camocim
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | adre
# Processing Record 4 of Set 2 | hamilton
# Processing Record 5 of Set 2 | nha trang
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | sibolga
# Processing Record 8 of Set 2 | sisimiut
# Processing Record 9 of Set 2 | salavat
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | sao filipe
# Processing Record 13 of Set 2 | tazovskiy
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | deputatskiy
# Processing Record 16 of Set 2 | deh rawud
# City not found. Skipping...
# Processing Record 17 of Set 2 | portland
# Processing Record 18 of Set 2 | pimentel
# Processing Record 19 of Set 2 | myitkyina
# Processing Record 20 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 2 | hansi
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | flinders
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | bocas del toro
# Processing Record 27 of Set 2 | luanda
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | dakar
# Processing Record 30 of Set 2 | half moon bay
# Processing Record 31 of Set 2 | churapcha
# Processing Record 32 of Set 2 | qinhuangdao
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | smithers
# Processing Record 36 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 2 | san quintin
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | poum
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | abalak
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | leshukonskoye
# Processing Record 46 of Set 2 | muros
# Processing Record 47 of Set 2 | saldanha
# Processing Record 48 of Set 2 | rio grande
# Processing Record 49 of Set 2 | akureyri
# Processing Record 50 of Set 2 | mumbwa
# Processing Record 1 of Set 3 | manta
# Processing Record 2 of Set 3 | champerico
# Processing Record 3 of Set 3 | marihatag
# Processing Record 4 of Set 3 | pevek
# Processing Record 5 of Set 3 | chokurdakh
# Processing Record 6 of Set 3 | lavrentiya
# Processing Record 7 of Set 3 | kwinana
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | xiongzhou
# Processing Record 12 of Set 3 | yellandu
# Processing Record 13 of Set 3 | port moresby
# Processing Record 14 of Set 3 | phoenix
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | gonbad-e qabus
# Processing Record 17 of Set 3 | ternate
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | bengkulu
# City not found. Skipping...
# Processing Record 20 of Set 3 | cambridge
# Processing Record 21 of Set 3 | balikpapan
# Processing Record 22 of Set 3 | camapua
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | la asuncion
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | lakes entrance
# Processing Record 31 of Set 3 | kamaishi
# Processing Record 32 of Set 3 | rizhao
# Processing Record 33 of Set 3 | bama
# Processing Record 34 of Set 3 | mnogovershinnyy
# Processing Record 35 of Set 3 | hobyo
# Processing Record 36 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 3 | port alfred
# Processing Record 38 of Set 3 | igrim
# Processing Record 39 of Set 3 | kaitangata
# Processing Record 40 of Set 3 | nikolskoye
# Processing Record 41 of Set 3 | lotofaga
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | krasnoselkup
# City not found. Skipping...
# Processing Record 44 of Set 3 | sonamura
# Processing Record 45 of Set 3 | mudanya
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | palamas
# Processing Record 48 of Set 3 | little current
# Processing Record 49 of Set 3 | launceston
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | dongsheng
# Processing Record 4 of Set 4 | waipawa
# Processing Record 5 of Set 4 | salalah
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | yar-sale
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | auki
# Processing Record 10 of Set 4 | katsuura
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | ukiah
# Processing Record 13 of Set 4 | port keats
# Processing Record 14 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 4 | haines junction
# Processing Record 18 of Set 4 | joao pinheiro
# Processing Record 19 of Set 4 | miguel pereira
# Processing Record 20 of Set 4 | hohhot
# Processing Record 21 of Set 4 | aykhal
# Processing Record 22 of Set 4 | stettler
# Processing Record 23 of Set 4 | kollam
# Processing Record 24 of Set 4 | richards bay
# Processing Record 25 of Set 4 | vanimo
# Processing Record 26 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 27 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 4 | ngunguru
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | kemijarvi
# City not found. Skipping...
# Processing Record 31 of Set 4 | bilma
# Processing Record 32 of Set 4 | amahai
# Processing Record 33 of Set 4 | ulaangom
# Processing Record 34 of Set 4 | ahome
# Processing Record 35 of Set 4 | santa catarina de tepehuanes
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | kishtwar
# Processing Record 38 of Set 4 | angra
# City not found. Skipping...
# Processing Record 39 of Set 4 | zhenlai
# Processing Record 40 of Set 4 | beidao
# Processing Record 41 of Set 4 | kenai
# Processing Record 42 of Set 4 | tari
# Processing Record 43 of Set 4 | hualmay
# Processing Record 44 of Set 4 | constitucion
# Processing Record 45 of Set 4 | konevo
# Processing Record 46 of Set 4 | maarianhamina
# City not found. Skipping...
# Processing Record 47 of Set 4 | chippewa falls
# Processing Record 48 of Set 4 | noyakert
# Processing Record 49 of Set 4 | vrangel
# Processing Record 50 of Set 4 | jiuquan
# Processing Record 1 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | havelock
# Processing Record 4 of Set 5 | tilichiki
# Processing Record 5 of Set 5 | fulitun
# City not found. Skipping...
# Processing Record 6 of Set 5 | umm kaddadah
# Processing Record 7 of Set 5 | butaritari
# Processing Record 8 of Set 5 | cabedelo
# Processing Record 9 of Set 5 | norman wells
# Processing Record 10 of Set 5 | musafirkhana
# Processing Record 11 of Set 5 | raton
# Processing Record 12 of Set 5 | belyy yar
# Processing Record 13 of Set 5 | mehamn
# Processing Record 14 of Set 5 | zyryanskoye
# Processing Record 15 of Set 5 | santa fe
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 5 | nuoro
# Processing Record 19 of Set 5 | sola
# Processing Record 20 of Set 5 | yeppoon
# Processing Record 21 of Set 5 | brus laguna
# Processing Record 22 of Set 5 | lapua
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | tuatapere
# Processing Record 25 of Set 5 | adrar
# Processing Record 26 of Set 5 | aitape
# Processing Record 27 of Set 5 | provideniya
# Processing Record 28 of Set 5 | caravelas
# Processing Record 29 of Set 5 | broome
# Processing Record 30 of Set 5 | bonavista
# Processing Record 31 of Set 5 | henties bay
# Processing Record 32 of Set 5 | nanortalik
# Processing Record 33 of Set 5 | nampula
# Processing Record 34 of Set 5 | antofagasta
# Processing Record 35 of Set 5 | cabo san lucas
# Processing Record 36 of Set 5 | gorontalo
# Processing Record 37 of Set 5 | chapais
# Processing Record 38 of Set 5 | weinan
# Processing Record 39 of Set 5 | mandali
# Processing Record 40 of Set 5 | longyearbyen
# Processing Record 41 of Set 5 | lira
# Processing Record 42 of Set 5 | seoul
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | hithadhoo
# Processing Record 46 of Set 5 | vila franca do campo
# Processing Record 47 of Set 5 | yuli
# Processing Record 48 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 5 | ligayan
# Processing Record 50 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 6 | garowe
# Processing Record 2 of Set 6 | duluth
# Processing Record 3 of Set 6 | natal
# Processing Record 4 of Set 6 | santa cruz
# Processing Record 5 of Set 6 | taltal
# Processing Record 6 of Set 6 | bitung
# Processing Record 7 of Set 6 | cavan
# Processing Record 8 of Set 6 | athabasca
# Processing Record 9 of Set 6 | port macquarie
# Processing Record 10 of Set 6 | fortuna
# Processing Record 11 of Set 6 | luganville
# Processing Record 12 of Set 6 | durban
# Processing Record 13 of Set 6 | kruisfontein
# Processing Record 14 of Set 6 | port elizabeth
# Processing Record 15 of Set 6 | abha
# Processing Record 16 of Set 6 | port lincoln
# Processing Record 17 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 18 of Set 6 | kainantu
# Processing Record 19 of Set 6 | kashi
# City not found. Skipping...
# Processing Record 20 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 6 | port hardy
# Processing Record 22 of Set 6 | herat
# Processing Record 23 of Set 6 | buin
# Processing Record 24 of Set 6 | wakkanai
# Processing Record 25 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 6 | chimore
# Processing Record 27 of Set 6 | dargaville
# Processing Record 28 of Set 6 | ostrovnoy
# Processing Record 29 of Set 6 | gwadar
# Processing Record 30 of Set 6 | tonneins
# Processing Record 31 of Set 6 | sechura
# Processing Record 32 of Set 6 | sulangan
# Processing Record 33 of Set 6 | kyenjojo
# Processing Record 34 of Set 6 | chaparral
# Processing Record 35 of Set 6 | ilulissat
# Processing Record 36 of Set 6 | tahta
# City not found. Skipping...
# Processing Record 37 of Set 6 | beyneu
# Processing Record 38 of Set 6 | cayenne
# Processing Record 39 of Set 6 | brzesko
# Processing Record 40 of Set 6 | comodoro rivadavia
# Processing Record 41 of Set 6 | sao joao da barra
# Processing Record 42 of Set 6 | jiazi
# Processing Record 43 of Set 6 | lewiston
# Processing Record 44 of Set 6 | namibe
# Processing Record 45 of Set 6 | huazolotitlan
# City not found. Skipping...
# Processing Record 46 of Set 6 | bayir
# Processing Record 47 of Set 6 | karratha
# Processing Record 48 of Set 6 | polunochnoye
# Processing Record 49 of Set 6 | sorland
# Processing Record 50 of Set 6 | vao
# Processing Record 1 of Set 7 | borlange
# City not found. Skipping...
# Processing Record 2 of Set 7 | orocue
# Processing Record 3 of Set 7 | bambous virieux
# Processing Record 4 of Set 7 | waiuku
# Processing Record 5 of Set 7 | botwood
# Processing Record 6 of Set 7 | michigan city
# Processing Record 7 of Set 7 | luau
# Processing Record 8 of Set 7 | abu kamal
# Processing Record 9 of Set 7 | tucuman
# Processing Record 10 of Set 7 | dorado
# Processing Record 11 of Set 7 | clyde river
# Processing Record 12 of Set 7 | rawson
# Processing Record 13 of Set 7 | taunggyi
# Processing Record 14 of Set 7 | prince george
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | kalinovskaya
# Processing Record 17 of Set 7 | salamiyah
# Processing Record 18 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | menuma
# Processing Record 21 of Set 7 | nipawin
# Processing Record 22 of Set 7 | roald
# Processing Record 23 of Set 7 | jimenez
# Processing Record 24 of Set 7 | coolum beach
# Processing Record 25 of Set 7 | bar harbor
# Processing Record 26 of Set 7 | krasnogorskoye
# Processing Record 27 of Set 7 | sakaiminato
# Processing Record 28 of Set 7 | cherskiy
# Processing Record 29 of Set 7 | qaqortoq
# Processing Record 30 of Set 7 | arlit
# Processing Record 31 of Set 7 | olafsvik
# City not found. Skipping...
# Processing Record 32 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 7 | maun
# Processing Record 34 of Set 7 | esperance
# Processing Record 35 of Set 7 | tombouctou
# Processing Record 36 of Set 7 | campbellton
# Processing Record 37 of Set 7 | saint george
# Processing Record 38 of Set 7 | necochea
# Processing Record 39 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 7 | zhigalovo
# Processing Record 41 of Set 7 | kalemie
# Processing Record 42 of Set 7 | rockingham
# Processing Record 43 of Set 7 | butterworth
# Processing Record 44 of Set 7 | waseca
# Processing Record 45 of Set 7 | zhigansk
# Processing Record 46 of Set 7 | talnakh
# Processing Record 47 of Set 7 | geraldton
# Processing Record 48 of Set 7 | kloulklubed
# Processing Record 49 of Set 7 | ahipara
# Processing Record 50 of Set 7 | pontes e lacerda
# Processing Record 1 of Set 8 | powell
# Processing Record 2 of Set 8 | traverse city
# Processing Record 3 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 4 of Set 8 | chulumani
# Processing Record 5 of Set 8 | bonnyville
# Processing Record 6 of Set 8 | ruteng
# Processing Record 7 of Set 8 | byron bay
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | jinchang
# Processing Record 10 of Set 8 | sebezh
# Processing Record 11 of Set 8 | college
# Processing Record 12 of Set 8 | abbeville
# Processing Record 13 of Set 8 | leningradskiy
# Processing Record 14 of Set 8 | huandacareo
# Processing Record 15 of Set 8 | lazaro cardenas
# Processing Record 16 of Set 8 | dubbo
# Processing Record 17 of Set 8 | carballo
# Processing Record 18 of Set 8 | lismore
# Processing Record 19 of Set 8 | zyryanka
# Processing Record 20 of Set 8 | nishihara
# Processing Record 21 of Set 8 | vestmanna
# Processing Record 22 of Set 8 | lahij
# Processing Record 23 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 24 of Set 8 | kupang
# Processing Record 25 of Set 8 | dukat
# Processing Record 26 of Set 8 | ketchenery
# City not found. Skipping...
# Processing Record 27 of Set 8 | sault sainte marie
# Processing Record 28 of Set 8 | lagunas
# Processing Record 29 of Set 8 | coquimbo
# Processing Record 30 of Set 8 | tumut
# Processing Record 31 of Set 8 | formosa do rio preto
# Processing Record 32 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 8 | neosho
# Processing Record 34 of Set 8 | de-kastri
# Processing Record 35 of Set 8 | jiaohe
# Processing Record 36 of Set 8 | marzuq
# Processing Record 37 of Set 8 | kysyl-syr
# Processing Record 38 of Set 8 | pangnirtung
# Processing Record 39 of Set 8 | narsaq
# Processing Record 40 of Set 8 | yerbogachen
# Processing Record 41 of Set 8 | atambua
# Processing Record 42 of Set 8 | khandyga
# Processing Record 43 of Set 8 | kalakamati
# Processing Record 44 of Set 8 | tubuala
# Processing Record 45 of Set 8 | belaya gora
# Processing Record 46 of Set 8 | huarmey
# Processing Record 47 of Set 8 | dombarovskiy
# Processing Record 48 of Set 8 | christchurch
# Processing Record 49 of Set 8 | lalin
# Processing Record 50 of Set 8 | darhan
# Processing Record 1 of Set 9 | bambanglipuro
# Processing Record 2 of Set 9 | camana
# City not found. Skipping...
# Processing Record 3 of Set 9 | turayf
# Processing Record 4 of Set 9 | santa ines
# Processing Record 5 of Set 9 | coihaique
# Processing Record 6 of Set 9 | yingkou
# Processing Record 7 of Set 9 | methven
# Processing Record 8 of Set 9 | nenjiang
# Processing Record 9 of Set 9 | viransehir
# Processing Record 10 of Set 9 | soe
# Processing Record 11 of Set 9 | santa rosalia
# Processing Record 12 of Set 9 | saint anthony
# Processing Record 13 of Set 9 | pozo colorado
# Processing Record 14 of Set 9 | eureka
# Processing Record 15 of Set 9 | wohlen
# Processing Record 16 of Set 9 | malakal
# City not found. Skipping...
# Processing Record 17 of Set 9 | dubovyy umet
# Processing Record 18 of Set 9 | estevan
# Processing Record 19 of Set 9 | tromso
# Processing Record 20 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 21 of Set 9 | carutapera
# Processing Record 22 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 9 | iqaluit
# Processing Record 24 of Set 9 | podgorica
# Processing Record 25 of Set 9 | ouesso
# Processing Record 26 of Set 9 | fuyu
# Processing Record 27 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 9 | cockburn town
# Processing Record 29 of Set 9 | arraial do cabo
# Processing Record 30 of Set 9 | kununurra
# Processing Record 31 of Set 9 | san policarpo
# Processing Record 32 of Set 9 | upington
# Processing Record 33 of Set 9 | belmonte
# Processing Record 34 of Set 9 | bathsheba
# Processing Record 35 of Set 9 | iracoubo
# Processing Record 36 of Set 9 | anloga
# Processing Record 37 of Set 9 | taoudenni
# Processing Record 38 of Set 9 | matagami
# Processing Record 39 of Set 9 | hamburg
# Processing Record 40 of Set 9 | banepa
# Processing Record 41 of Set 9 | santarem
# City not found. Skipping...
# Processing Record 42 of Set 9 | dayong
# Processing Record 43 of Set 9 | shimoda
# Processing Record 44 of Set 9 | inirida
# Processing Record 45 of Set 9 | port said
# Processing Record 46 of Set 9 | antalaha
# Processing Record 47 of Set 9 | eyl
# Processing Record 48 of Set 9 | whitehorse
# Processing Record 49 of Set 9 | abu samrah
# Processing Record 50 of Set 9 | irtyshskiy
# Processing Record 1 of Set 10 | finnsnes
# Processing Record 2 of Set 10 | yatou
# Processing Record 3 of Set 10 | manicore
# Processing Record 4 of Set 10 | ca mau
# Processing Record 5 of Set 10 | luderitz
# Processing Record 6 of Set 10 | marsh harbour
# Processing Record 7 of Set 10 | lima
# Processing Record 8 of Set 10 | lieksa
# Processing Record 9 of Set 10 | vaovai
# City not found. Skipping...
# Processing Record 10 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 11 of Set 10 | ijui
# Processing Record 12 of Set 10 | along
# Processing Record 13 of Set 10 | acarau
# City not found. Skipping...
# Processing Record 14 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 15 of Set 10 | maragogipe
# Processing Record 16 of Set 10 | lodja
# Processing Record 17 of Set 10 | gueret
# Processing Record 18 of Set 10 | melito di porto salvo
# Processing Record 19 of Set 10 | naze
# Processing Record 20 of Set 10 | ontario
# Processing Record 21 of Set 10 | banda aceh
# Processing Record 22 of Set 10 | saint-augustin
# Processing Record 23 of Set 10 | ketchikan
# Processing Record 24 of Set 10 | praia da vitoria
# Processing Record 25 of Set 10 | alta floresta
# Processing Record 26 of Set 10 | mount gambier
# Processing Record 27 of Set 10 | hibbing
# Processing Record 28 of Set 10 | san clemente
# Processing Record 29 of Set 10 | muisne
# Processing Record 30 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 31 of Set 10 | abdanan
# Processing Record 32 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 10 | tocopilla
# Processing Record 34 of Set 10 | qasigiannguit
# Processing Record 35 of Set 10 | pacific grove
# Processing Record 36 of Set 10 | el alto
# Processing Record 37 of Set 10 | tateyama
# Processing Record 38 of Set 10 | zhashkiv
# Processing Record 39 of Set 10 | kieta
# Processing Record 40 of Set 10 | aparecida do taboado
# Processing Record 41 of Set 10 | bardiyah
# City not found. Skipping...
# Processing Record 42 of Set 10 | netarhat
# Processing Record 43 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 44 of Set 10 | aguimes
# Processing Record 45 of Set 10 | morondava
# Processing Record 46 of Set 10 | saint-joseph
# Processing Record 47 of Set 10 | mme
# City not found. Skipping...
# Processing Record 48 of Set 10 | nhulunbuy
# Processing Record 49 of Set 10 | saint-francois
# Processing Record 50 of Set 10 | lagoa
# Processing Record 1 of Set 11 | savannah bight
# Processing Record 2 of Set 11 | ichinoseki
# Processing Record 3 of Set 11 | guerrero negro
# Processing Record 4 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 11 | kismayo
# City not found. Skipping...
# Processing Record 6 of Set 11 | getulio vargas
# Processing Record 7 of Set 11 | roanne
# Processing Record 8 of Set 11 | los llanos de aridane
# Processing Record 9 of Set 11 | camalu
# Processing Record 10 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 11 | goundam
# Processing Record 12 of Set 11 | kirakira
# Processing Record 13 of Set 11 | konya
# Processing Record 14 of Set 11 | svetlogorsk
# Processing Record 15 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 16 of Set 11 | nago
# Processing Record 17 of Set 11 | khonsa
# Processing Record 18 of Set 11 | solnechnyy
# Processing Record 19 of Set 11 | lufilufi
# Processing Record 20 of Set 11 | kautokeino
# Processing Record 21 of Set 11 | oudtshoorn
# Processing Record 22 of Set 11 | omutninsk
# Processing Record 23 of Set 11 | mazagao
# Processing Record 24 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 11 | ayr
# Processing Record 27 of Set 11 | nikel
# Processing Record 28 of Set 11 | nizwa
# Processing Record 29 of Set 11 | bunia
# Processing Record 30 of Set 11 | tessalit
# Processing Record 31 of Set 11 | warrnambool
# Processing Record 32 of Set 11 | labuhan
# Processing Record 33 of Set 11 | kiama
# Processing Record 34 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 11 | maldonado
# Processing Record 36 of Set 11 | flin flon
# Processing Record 37 of Set 11 | sharjah
# Processing Record 38 of Set 11 | rosa zarate
# Processing Record 39 of Set 11 | diapaga
# Processing Record 40 of Set 11 | neuquen
# Processing Record 41 of Set 11 | san cristobal
# Processing Record 42 of Set 11 | mabaruma
# Processing Record 43 of Set 11 | taksimo
# Processing Record 44 of Set 11 | bima
# Processing Record 45 of Set 11 | chhatak
# Processing Record 46 of Set 11 | dunmore east
# Processing Record 47 of Set 11 | dalbandin
# Processing Record 48 of Set 11 | novyy urengoy
# Processing Record 49 of Set 11 | toguchin
# Processing Record 50 of Set 11 | lerwick
# Processing Record 1 of Set 12 | praya
# Processing Record 2 of Set 12 | nanga eboko
# Processing Record 3 of Set 12 | miyang
# Processing Record 4 of Set 12 | curup
# Processing Record 5 of Set 12 | santiago del estero
# Processing Record 6 of Set 12 | port hawkesbury
# Processing Record 7 of Set 12 | jiexiu
# Processing Record 8 of Set 12 | darnah
# Processing Record 9 of Set 12 | bilibino
# Processing Record 10 of Set 12 | ciro marina
# Processing Record 11 of Set 12 | sawtell
# Processing Record 12 of Set 12 | southbridge
# Processing Record 13 of Set 12 | alofi
# Processing Record 14 of Set 12 | dinghai
# Processing Record 15 of Set 12 | castelletto sopra ticino
# Processing Record 16 of Set 12 | awassa
# City not found. Skipping...
# Processing Record 17 of Set 12 | amga
# Processing Record 18 of Set 12 | san ramon
# Processing Record 19 of Set 12 | hammerfest
# Processing Record 20 of Set 12 | yeniseysk
# Processing Record 21 of Set 12 | gizo
# Processing Record 22 of Set 12 | kortkeros
# Processing Record 23 of Set 12 | jutai
# Processing Record 24 of Set 12 | merauke
# Processing Record 25 of Set 12 | marinette
# Processing Record 26 of Set 12 | faya
# Processing Record 27 of Set 12 | nileshwar
# Processing Record 28 of Set 12 | canatlan
# Processing Record 29 of Set 12 | fukue
# Processing Record 30 of Set 12 | ixtapa
# Processing Record 31 of Set 12 | mozarlandia
# Processing Record 32 of Set 12 | yumaguzino
# Processing Record 33 of Set 12 | pocking
# Processing Record 34 of Set 12 | melilla
# Processing Record 35 of Set 12 | pionerskiy
# Processing Record 36 of Set 12 | katangli
# Processing Record 37 of Set 12 | novo aripuana
# Processing Record 38 of Set 12 | batticaloa
# Processing Record 39 of Set 12 | barra do bugres
# Processing Record 40 of Set 12 | chapada dos guimaraes
# Processing Record 41 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 12 | soloneshnoye
# Processing Record 43 of Set 12 | weligama
# Processing Record 44 of Set 12 | marshall
# Processing Record 45 of Set 12 | prince rupert
# Processing Record 46 of Set 12 | nurota
# Processing Record 47 of Set 12 | divnomorskoye
# Processing Record 48 of Set 12 | trelew
# Processing Record 49 of Set 12 | vila
# Processing Record 50 of Set 12 | tomatlan
# Processing Record 1 of Set 13 | mecca
# Processing Record 2 of Set 13 | chabahar
# Processing Record 3 of Set 13 | severo-yeniseyskiy
# Processing Record 4 of Set 13 | vermillion
# Processing Record 5 of Set 13 | salta
# Processing Record 6 of Set 13 | kaduqli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

city_data_df.sort_values(["Max Temp"])
# Out:
#                 City Country                 Date    Lat     Lng  Max Temp  \
# 303         Zhigansk      RU  2019-11-06 18:34:00  66.77  123.37    -18.93
# 175        Saskylakh      RU  2019-11-06 18:33:39  71.97  114.09    -17.49
# 341        Kysyl-Syr      RU  2019-11-06 18:34:06  63.90  122.77    -14.43
# 151           Aykhal      RU  2019-11-06 18:33:33  65.95  111.51    -13.01
# 67         Churapcha      RU  2019-11-06 18:33:17  62.00  132.43    -11.46
# ..               ...     ...                  ...    ...     ...       ...
# 39           Camocim      BR  2019-11-06 18:33:13  -2.90  -40.84     95.74
# 106          Camapua      BR  2019-11-06 18:33:23 -19.53  -54.04     96.48
# 518    Novo Aripuana      BR  2019-11-06 18:34:38  -5.12  -60.38     96.93
# 333          Lagunas      PE  2019-11-06 18:34:05  -5.23  -75.68     97.72
# 520  Barra Do Bugres      BR  2019-11-06 18:34:38 -15.07  -57.19    102.06
#
#      Humidity  Cloudiness  Wind Speed
# 303        97          44        3.44
# 175        97           0        7.27
# 341        97           0        3.74
# 151        83         100        4.47
# 67         96         100        7.16
# ..        ...         ...         ...
# 39         36           0       12.75
# 106        33          97        5.91
# 518        38          97        3.22
# 333        39          17        1.97
# 520        31          90        2.75
#
# [537 rows x 9 columns]

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
import time
today = time.time()
today = time.strftime("%x")
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")

# %%
from scipy.stats import linregress
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#creating dfs for northern/souther hemispheres
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
#call function
plot_linear_regression(x_values, y_values,
                       """Linear Regression on the Northern Hemisphere \n
                       for Maximum Temperature""", "Max Temp",(0,-20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       """Linear Regression on the Southern Hemisphere \n
                        for Maximum Temperature""", 'Max Temp',(-50,100))

# %%
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.6242443105045831, intercept=85.66336237377095, rvalue=0.612164717099356, pvalue=1.5000816664752609e-18, stderr=0.0627729718593187)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       """Linear Regression on the Northern Hemisphere \n
                        for % Humidity""", '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       """Linear Regression on the Southern Hemisphere \n
                        for % Humidity""", '% Humidity',(-50,15))

# %%
#linear regression on the Southern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
#call the function
plot_linear_regression(x_values, y_values,
                      """Linear Regression on the Northern Hemisphere \n
                      for % Cloudiness""", "% Cloudiness", (10, 60))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       """Linear Regression on the Southern Hemisphere \n
                        for % Cloudiness""", '% Cloudiness',(-50,60))
# Out:
# LinregressResult(slope=-0.21767439169095154, intercept=46.23679947636147, rvalue=-0.081152739068252, pvalue=0.2971482828304368, stderr=0.20812649651497628)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       """Linear Regression on the Northern Hemisphere \n
                        for Wind Speed""", 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       """Linear Regression on the Southern Hemisphere \n
                        for Wind Speed""", 'Wind Speed',(-50,35))
